# %%
import igraph as ig
import networkx as nx
import matplotlib.pyplot as plt

# %%
from igraph import Graph, Layout
import igraph as ig
karate = Graph.Famous("Zachary")
layout = karate.layout_kamada_kawai()
visual_style={"bbox": (300, 300), "margin": 15, "layout": layout}

cl = karate.community_fastgreedy()
membership = cl.as_clustering().membership
pal = ig.drawing.colors.ClusterColoringPalette(len(membership))
karate.vs["color"] = pal.get_many(cl.as_clustering().membership)
karate.vs["size"] = 15

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ig.plot(karate, target=ax)

# %%
centralities = karate.closeness()
karate.vs['size'] = [c * 50 for c in centralities]

fig, ax = plt.subplots()
ig.plot(
    karate, 
    target=ax,
    edge_width=0.2
)

# %%
betweenness_centralities = karate.betweenness()
closeness_centralities = karate.closeness()
degrees = karate.degree()
in_degrees = karate.degree(mode='in')
out_degrees = karate.degree(mode='out')
clustering_coeffs = karate.transitivity_local_undirected(vertices=None)
pagerank_centralities = karate.pagerank()
